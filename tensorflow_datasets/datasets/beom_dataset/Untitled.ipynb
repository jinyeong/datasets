# %%
# %%bash
# tfds build \
# --manual_dir=gs://lg-maxtext/test-dataset1 \
# --data_dir=gs://dataset-temp-dataflow/beom/test1 \
# --beam_pipeline_options=\
# "runner=DataflowRunner,"\
# "project=lg-air-pso,"\
# "region=us-west1,"\
# "job_name=beom-test-job,"\
# "staging_location=gs://dataset-temp-dataflow/beom/binaries,"\
# "temp_location=gs://dataset-temp-dataflow/beom/temp,"\
# "requirements_file=/home/jupyter/beom_dataset/beam_requirements.txt"
#
# # pip install google-apitools 깔기
# Out:
# 2024-02-26 08:39:34.167046: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 08:39:34.229694: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 08:39:34.229798: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 08:39:34.232469: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 08:39:34.247600: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
# %pip install google-apitools
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%bash
# python -m tensorflow_datasets.scripts.download_and_prepare \
#   --manual_dir=gs://lg-maxtext/test-dataset1 \
#   --data_dir=gs://dataset-temp-dataflow/beom/test1 \
#   --beam_pipeline_options=\
# "runner=DataflowRunner,project=lg-air-pso,job_name=beom-dataset-gen,"\
# "region=us,"\
# "staging_location=gs://dataset-temp-dataflow/beom/binaries,"\
# "temp_location=gs://dataset-temp-dataflow/beom/temp,"\
# "requirements_file=/home/jupyter/beom_dataset/beam_requirements.txt"
# Out:
# W0226 08:27:57.319593 140445046204224 download_and_prepare.py:46] ***`tfds build` should be used instead of `download_and_prepare`.***
# 2024-02-26 08:27:57.658725: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 08:27:57.713994: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 08:27:57.714093: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 08:27:57.715683: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %pip install apache_beam[gcp]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 2.5 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.25.3 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.
